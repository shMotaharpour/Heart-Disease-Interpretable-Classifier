# %%
from project_lib import BinaryClassificationModelsScoring

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
tst = BinaryClassificationModelsScoring('test')
tst
# Out:
# [test] scores table with 0 records

# %%
tst.score_table
# Out:
# Empty DataFrame
# Columns: [(train, accuracy), (train, recall), (train, precision), (train, roc_auc), (train, f1), (train, average_precision), (test, accuracy), (test, recall), (test, precision), (test, roc_auc), (test, f1), (test, average_precision)]
# Index: []

# %%
rf = RandomForestClassifier(n_estimators=10, min_samples_leaf=3)
tst.train_and_scoring(rf)
# Out:
# Level          train                                                    \
# score       accuracy recall precision roc_auc     f1 average_precision
# test models
#                0.861  0.781     0.901   0.938  0.837             0.931
#
# Level           test
# score       accuracy recall precision roc_auc     f1 average_precision
# test models
#                0.783  0.636     0.875   0.932  0.737             0.934

# %%
tst.last_result
# Out:
# Level          train                                                    \
# score       accuracy recall precision roc_auc     f1 average_precision
# test models
#                0.861  0.781     0.901   0.938  0.837             0.931
#
# Level           test
# score       accuracy recall precision roc_auc     f1 average_precision
# test models
#                0.783  0.636     0.875   0.932  0.737             0.934

# %%
tst.score_table
# Out:
# Empty DataFrame
# Columns: [(train, accuracy), (train, recall), (train, precision), (train, roc_auc), (train, f1), (train, average_precision), (test, accuracy), (test, recall), (test, precision), (test, roc_auc), (test, f1), (test, average_precision)]
# Index: []

# %%
tst.dump_last_result()
tst.score_table
# Out:
# Level          train                                                    \
# score       accuracy recall precision roc_auc     f1 average_precision
# test models
#                0.861  0.781     0.901   0.938  0.837             0.931
#
# Level           test
# score       accuracy recall precision roc_auc     f1 average_precision
# test models
#                0.783  0.636     0.875   0.932  0.737             0.934

# %%
tst.dump_last_result('random Forest')
tst.score_table
# Out:
# Level            train                                                    \
# score         accuracy recall precision roc_auc     f1 average_precision
# test models
#                  0.861  0.781     0.901   0.938  0.837             0.931
# random Forest    0.861  0.781     0.901   0.938  0.837             0.931
#
# Level             test
# score         accuracy recall precision roc_auc     f1 average_precision
# test models
#                  0.783  0.636     0.875   0.932  0.737             0.934
# random Forest    0.783  0.636     0.875   0.932  0.737             0.934

# %%
tst.save_table()

# %%
df_lin2 = BinaryClassificationModelsScoring('test')
df_lin2
# Out:
# Model scoring table: [test]

# %%
b = df_lin2.last_result
b
# Out:
# Empty DataFrame
# Columns: [(train, accuracy), (train, recall), (train, precision), (train, roc_auc), (train, f1), (train, average_precision), (test, accuracy), (test, recall), (test, precision), (test, roc_auc), (test, f1), (test, average_precision)]
# Index: []

# %%
df_lin2.score_table
# Out:
# Level            train                                                    \
# score         accuracy recall precision roc_auc     f1 average_precision
# test models
#                  0.864  0.812     0.881   0.937  0.846             0.931
# random Forest    0.864  0.812     0.881   0.937  0.846             0.931
#
# Level             test
# score         accuracy recall precision roc_auc   f1 average_precision
# test models
#                  0.826  0.727     0.889   0.939  0.8             0.951
# random Forest    0.826  0.727     0.889   0.939  0.8             0.951

# %%
rf2 = RandomForestClassifier(n_estimators=20, min_samples_leaf=7)
df_lin2.train_and_scoring(rf2)
# Out:
# Level          train                                                    \
# score       accuracy recall precision roc_auc     f1 average_precision
# test models
#                0.854  0.766     0.899   0.925  0.827             0.918
#
# Level           test
# score       accuracy recall precision roc_auc     f1 average_precision
# test models
#                 0.87  0.727       1.0   0.932  0.842             0.944

# %%
df_lin2.last_result
# Out:
# Level          train                                                    \
# score       accuracy recall precision roc_auc     f1 average_precision
# test models
#                0.854  0.766     0.899   0.925  0.827             0.918
#
# Level           test
# score       accuracy recall precision roc_auc     f1 average_precision
# test models
#                 0.87  0.727       1.0   0.932  0.842             0.944

# %%
tst.last_result
# Out:
# Level          train                                                    \
# score       accuracy recall precision roc_auc     f1 average_precision
# test models
#                0.864  0.812     0.881   0.937  0.846             0.931
#
# Level           test
# score       accuracy recall precision roc_auc   f1 average_precision
# test models
#                0.826  0.727     0.889   0.939  0.8             0.951

# %%
df_lin2.dump_last_result('second RF')

# %%
tst.score_table
# Out:
# Level            train                                                    \
# score         accuracy recall precision roc_auc     f1 average_precision
# test models
#                  0.864  0.812     0.881   0.937  0.846             0.931
# random Forest    0.864  0.812     0.881   0.937  0.846             0.931
# second RF        0.854  0.766     0.899   0.925  0.827             0.918
#
# Level             test
# score         accuracy recall precision roc_auc     f1 average_precision
# test models
#                  0.826  0.727     0.889   0.939    0.8             0.951
# random Forest    0.826  0.727     0.889   0.939    0.8             0.951
# second RF         0.87  0.727       1.0   0.932  0.842             0.944
